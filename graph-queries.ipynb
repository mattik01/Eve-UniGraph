# %%
import networkx as nx
from tqdm.notebook import tqdm
from functions import *

# %% [markdown]
# #### Put and execute queries on the graph to answer all questions you have !

# %%
# Load graph
BACKUP_GRAPH_PATH = 'eve_universe_backup.graphml'
GRAPH_PATH = 'eve_universe.graphml'

G = nx.read_graphml(GRAPH_PATH)
print(f"Loaded graph with {len(G.nodes)} nodes and {len(G.edges)} edges.\n")
node_check(G)
# Out:
# Loaded graph with 8436 nodes and 6888 edges.
#
# Loaded table with 8436 systems.
#
# HS:
# Node 30023489:
#   name: Fora
#   system_name: Fora
#   security_status: 0.9128799438476562
#   security_class: A
#   constellation_id: 20000334
#   star_id: 40339201.0
#   planet_count: 8
#   moon_count: 14
#   station_count: 1
#   stations: 60015022
#   has_stargates: True
#   region_id: 10000043
#   region_name: Domain
#   constellation_name: Norgoh
#   faction_name: Amarr
#   industry_manufacturing: 0.0127
#   industry_researching_time_efficiency: 0.0014
#   industry_researching_material_efficiency: 0.0014
#   industry_copying: 0.0014
#   industry_invention: 0.0014
#   industry_reaction: 0.0014
#   Connected systems:
#     - Eba (ID: 30002281)
#
# LS:
# Node 30004277:
#   name: Ajna
#   system_name: Ajna
#   security_status: 0.1853875964879989
#   security_class: B3
#   constellation_id: 20000625
#   star_id: 40270855.0
#   planet_count: 8
#   moon_count: 54
#   station_count: 2
#   stations: 60008833,60014647
#   has_stargates: True
#   region_id: 10000054
#   region_name: Aridia
#   constellation_name: Helab
#   faction_name: Amarr
#   industry_manufacturing: 0.0014
#   industry_researching_time_efficiency: 0.0014
#   industry_researching_material_efficiency: 0.0014
#   industry_copying: 0.0014
#   industry_invention: 0.0014
#   industry_reaction: 0.0014
#   Connected systems:
#     - Soliara (ID: 30004273)
#     - Sheri (ID: 30004278)
#     - Ahraghen (ID: 30004279)
#
# NS:
# Node 30002476:
#   name: G-73MR
#   system_name: G-73MR
#   security_status: -0.0267586335539817
#   security_class: H
#   constellation_id: 20000363
#   star_id: 40157461.0
#   planet_count: 7
#   moon_count: 55
#   station_count: 0
#   stations: nan
#   has_stargates: True
#   region_id: 10000029
#   region_name: Geminate
#   constellation_name: F-ZNNG
#   faction_name: None
#   industry_manufacturing: 0.0014
#   industry_researching_time_efficiency: 0.0014
#   industry_researching_material_efficiency: 0.0014
#   industry_copying: 0.0014
#   industry_invention: 0.0014
#   industry_reaction: 0.0014
#   Connected systems:
#     - TJM-JJ (ID: 30002474)
#     - AD-5B8 (ID: 30002478)
#     - E-91FV (ID: 30002477)
#     - 54-MF6 (ID: 30002480)
#
# WH:
# Node 30002161:
#   name: LBA-SO
#   system_name: LBA-SO
#   security_status: -0.2740895450115204
#   security_class: I1
#   constellation_id: 20000318
#   star_id: 40137852.0
#   planet_count: 10
#   moon_count: 64
#   station_count: 0
#   stations: nan
#   has_stargates: True
#   region_id: 10000025
#   region_name: Immensea
#   constellation_name: EL8Z-M
#   faction_name: None
#   industry_manufacturing: 0.0014
#   industry_researching_time_efficiency: 0.0014
#   industry_researching_material_efficiency: 0.0014
#   industry_copying: 0.0014
#   industry_invention: 0.0014
#   industry_reaction: 0.0014
#   Connected systems:
#     - E8-YS9 (ID: 30002163)
#     - AC-7LZ (ID: 30002160)

# %% [markdown]
# ### Abyss running hub finder

# %%
### Abyss running system
find_abyss_hubs(
    G=G,
    start_system="Jita",
    target_sec=0.6, 
    inclusion_vector=[0.5, 0.7, 0.8],       # Securitiy systems you want close by
    inclusion_max_jumps=3,                  # range for additional security systems
    use_avoid_list=True,                    # for the route finder
    only_hs=False,                          # for the route finder
    max_search_range=30,                    # for the route finder
    quiet_weights=(0.5, 0.4, 0.1),          # ship+pod kills, Jumps in space, Npc kills
    quiet_days=10000,                       # limit for averaging of player activitiy entries in the system
    verbose=False
)
# Out:
# --- Halenan (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 25.00 (from Jita) | Lowsec jumps: 10 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sosan, Tararan, Halmah]
#   Quiet: 4.00  (s+pk: 0.0, j: 10.0, NPCk: 0.0)
#   Close Alt Sec Systems:
#     ↳ Arveyil              (sec 0.5) | 2.00 jumps | QF: 5.00  (s+pk: 0.0, j: 5.0, NPCk: 0.0)
#     ↳ Ulerah               (sec 0.7) | 1.00 jumps | QF: 34.00  (s+pk: 0.0, j: 6.0, NPCk: 28.0)
#     ↳ Nidebora             (sec 0.8) | 2.00 jumps | QF: 25.00  (s+pk: 0.0, j: 7.0, NPCk: 18.0)
#   Closest Triglavian Buyer Systems:
#     → Mormelot             (sec 0.2) | 10.00 jumps | Buy vol: 1111 | QF: 92.00 | LS: Halmah, Tararan, Sosan, Oyonata, Kurniainen, Saidusairos, Gratesier, Schoorasana, Mormelot
#     → Evati                (sec 0.2) | 11.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Evati
#     → Lasleinur            (sec 0.2) | 11.00 jumps | Buy vol: 2222 | QF: 232.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Lasleinur
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Uktiad (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 26.00 (from Jita) | Lowsec jumps: 10 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sosan, Tararan, Halmah]
#   Quiet: 4.00  (s+pk: 0.0, j: 5.0, NPCk: 20.0)
#   Close Alt Sec Systems:
#     ↳ Arveyil              (sec 0.5) | 1.00 jumps | QF: 5.00  (s+pk: 0.0, j: 5.0, NPCk: 0.0)
#     ↳ Ulerah               (sec 0.7) | 2.00 jumps | QF: 34.00  (s+pk: 0.0, j: 6.0, NPCk: 28.0)
#     ↳ Nidebora             (sec 0.8) | 3.00 jumps | QF: 25.00  (s+pk: 0.0, j: 7.0, NPCk: 18.0)
#   Closest Triglavian Buyer Systems:
#     → Mormelot             (sec 0.2) | 11.00 jumps | Buy vol: 1111 | QF: 92.00 | LS: Halmah, Tararan, Sosan, Oyonata, Kurniainen, Saidusairos, Gratesier, Schoorasana, Mormelot
#     → Evati                (sec 0.2) | 12.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Evati
#     → Lasleinur            (sec 0.2) | 12.00 jumps | Buy vol: 2222 | QF: 232.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Lasleinur
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Phoren (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 6.90  (s+pk: 0.0, j: 12.0, NPCk: 21.0)
#   Close Alt Sec Systems:
#     ↳ Siyi                 (sec 0.5) | 3.00 jumps | QF: 148.00  (s+pk: 0.0, j: 10.0, NPCk: 138.0)
#     ↳ Ahkour               (sec 0.7) | 2.00 jumps | QF: 79.00  (s+pk: 0.0, j: 5.0, NPCk: 74.0)
#     ↳ Yanuel               (sec 0.8) | 2.00 jumps | QF: 39.00  (s+pk: 0.0, j: 39.0, NPCk: 0.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 3.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 4.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#     → Pimebeka             (sec 0.7) | 4.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Lour (Solitude) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 15 [Olettiers, Mesybier, PF-346, FD-MLJ, X-BV98, Poitot, F67E-Q, MHC-R3, 6E-578, ZVN5-H, 8-JYPM, M2-CF1, 97X-CH, Y9G-KS, Pertnineere]
#   Quiet: 7.60  (s+pk: 0.0, j: 19.0, NPCk: 0.0)
#   Close Alt Sec Systems:
#     ↳ Boystin              (sec 0.5) | 1.00 jumps | QF: 94.00  (s+pk: 0.0, j: 33.0, NPCk: 61.0)
#     ↳ Maire                (sec 0.7) | 1.00 jumps | QF: 151.00  (s+pk: 0.0, j: 30.0, NPCk: 121.0)
#     ↳ Yvaeroure            (sec 0.8) | 3.00 jumps | QF: 122.00  (s+pk: 0.0, j: 20.0, NPCk: 102.0)
#   Closest Triglavian Buyer Systems:
#     → Reblier              (sec 0.4) | 9.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, EZA-FM, 6-CZ49, Reblier
#     → Sortet               (sec 0.8) | 14.00 jumps | Buy vol: 2222 | QF: 370.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, EZA-FM, 6-CZ49, Reblier
#     → Aulbres              (sec 0.1) | 15.00 jumps | Buy vol: 5555 | QF: 190.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, ZVN5-H, 6E-578, MHC-R3, Harroule, Ostingele, Alperaute, Aunsou, Gare, Aulbres
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Mili (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 24.00 (from Jita) | Lowsec jumps: 10 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sosan, Tararan, Halmah]
#   Quiet: 7.90  (s+pk: 0.0, j: 12.0, NPCk: 31.0)
#   Close Alt Sec Systems:
#     ↳ Arveyil              (sec 0.5) | 3.00 jumps | QF: 5.00  (s+pk: 0.0, j: 5.0, NPCk: 0.0)
#     ↳ Ulerah               (sec 0.7) | 2.00 jumps | QF: 34.00  (s+pk: 0.0, j: 6.0, NPCk: 28.0)
#     ↳ Nidebora             (sec 0.8) | 3.00 jumps | QF: 25.00  (s+pk: 0.0, j: 7.0, NPCk: 18.0)
#   Closest Triglavian Buyer Systems:
#     → Mormelot             (sec 0.2) | 9.00 jumps | Buy vol: 1111 | QF: 92.00 | LS: Halmah, Tararan, Sosan, Oyonata, Kurniainen, Saidusairos, Gratesier, Schoorasana, Mormelot
#     → Evati                (sec 0.2) | 10.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Evati
#     → Lasleinur            (sec 0.2) | 10.00 jumps | Buy vol: 2222 | QF: 232.00 | LS: Halmah, Tararan, Arzad, Ezzara, Vard, Amamake, Gulmorogod, Egmar, Arnher, Lasleinur
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Joamma (Kador) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 25.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 8.00  (s+pk: 0.0, j: 5.0, NPCk: 60.0)
#   Close Alt Sec Systems:
#     ↳ Ghesis               (sec 0.5) | 1.00 jumps | QF: 196.00  (s+pk: 0.0, j: 93.0, NPCk: 103.0)
#     ↳ Gamdis               (sec 0.7) | 2.00 jumps | QF: 94.00  (s+pk: 0.0, j: 63.0, NPCk: 31.0)
#     ↳ Joramok              (sec 0.8) | 3.00 jumps | QF: 34.00  (s+pk: 0.0, j: 9.0, NPCk: 25.0)
#   Closest Triglavian Buyer Systems:
#     → Mamenkhanar          (sec 0.7) | 7.00 jumps | Buy vol: 2222 | QF: 68.00 | LS: Gonan
#     → Tash-Murkon Prime    (sec 0.8) | 8.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 9.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Imeshasa (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 8.00  (s+pk: 0.0, j: 20.0, NPCk: 0.0)
#   Close Alt Sec Systems:
#     ↳ Mimen                (sec 0.5) | 2.00 jumps | QF: 50.00  (s+pk: 0.0, j: 14.0, NPCk: 36.0)
#     ↳ Nafomeh              (sec 0.7) | 2.00 jumps | QF: 121.00  (s+pk: 0.0, j: 55.0, NPCk: 66.0)
#     ↳ Khopa                (sec 0.8) | 3.00 jumps | QF: 427.00  (s+pk: 0.0, j: 108.0, NPCk: 319.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 3.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 4.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Tividu               (sec 0.6) | 4.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Gaknem (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 9.20  (s+pk: 0.0, j: 12.0, NPCk: 44.0)
#   Close Alt Sec Systems:
#     ↳ Siyi                 (sec 0.5) | 2.00 jumps | QF: 148.00  (s+pk: 0.0, j: 10.0, NPCk: 138.0)
#     ↳ Ahkour               (sec 0.7) | 1.00 jumps | QF: 79.00  (s+pk: 0.0, j: 5.0, NPCk: 74.0)
#     ↳ Baviasi              (sec 0.8) | 3.00 jumps | QF: 259.00  (s+pk: 2.0, j: 66.0, NPCk: 191.0)
#   Closest Triglavian Buyer Systems:
#     → Pimebeka             (sec 0.7) | 4.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 4.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 5.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Tividu (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 10.50  (s+pk: 0.0, j: 15.0, NPCk: 45.0)
#   Close Alt Sec Systems:
#     ↳ Anjedin              (sec 0.5) | 1.00 jumps | QF: 156.00  (s+pk: 0.0, j: 111.0, NPCk: 45.0)
#     ↳ Pimebeka             (sec 0.7) | 2.00 jumps | QF: 430.00  (s+pk: 0.0, j: 150.0, NPCk: 280.0)
#     ↳ Armala               (sec 0.8) | 3.00 jumps | QF: 147.00  (s+pk: 0.0, j: 49.0, NPCk: 98.0)
#   Closest Triglavian Buyer Systems:
#     → Tividu               (sec 0.6) | 0.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Goram                (sec 0.6) | 1.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Pimebeka             (sec 0.7) | 2.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Lower Debyl (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 12 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Sosala, Kamela]
#   Quiet: 10.90  (s+pk: 0.0, j: 16.0, NPCk: 45.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 2.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Laddiaha             (sec 0.7) | 1.00 jumps | QF: 66.00  (s+pk: 0.0, j: 23.0, NPCk: 43.0)
#     ↳ Uadelah              (sec 0.8) | 2.00 jumps | QF: 370.00  (s+pk: 0.0, j: 320.0, NPCk: 50.0)
#   Closest Triglavian Buyer Systems:
#     → Asabona              (sec 0.3) | 8.00 jumps | Buy vol: 1111 | QF: 56.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona
#     → Asghatil             (sec 0.8) | 9.00 jumps | Buy vol: 2222 | QF: 35.00 | LS: Rahadalon, Nakah, Hasateem, Gomati
#     → Esteban              (sec 0.6) | 9.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Unkah (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 11.50  (s+pk: 0.0, j: 10.0, NPCk: 75.0)
#   Close Alt Sec Systems:
#     ↳ Mimen                (sec 0.5) | 1.00 jumps | QF: 50.00  (s+pk: 0.0, j: 14.0, NPCk: 36.0)
#     ↳ Sinid                (sec 0.7) | 2.00 jumps | QF: 101.00  (s+pk: 0.0, j: 21.0, NPCk: 80.0)
#     ↳ Mani                 (sec 0.8) | 3.00 jumps | QF: 265.00  (s+pk: 0.0, j: 55.0, NPCk: 210.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 4.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Asesamy              (sec 0.6) | 5.00 jumps | Buy vol: 2222 | QF: 121.00 | LS: Hoona
#     → Hilaban              (sec 0.9) | 5.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Ehnoum (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 12 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Sosala, Kamela]
#   Quiet: 13.40  (s+pk: 0.0, j: 15.0, NPCk: 74.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 1.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Upper Debyl          (sec 0.7) | 1.00 jumps | QF: 2.00  (s+pk: 0.0, j: 2.0, NPCk: 0.0)
#     ↳ Uadelah              (sec 0.8) | 3.00 jumps | QF: 370.00  (s+pk: 0.0, j: 320.0, NPCk: 50.0)
#   Closest Triglavian Buyer Systems:
#     → Asabona              (sec 0.3) | 7.00 jumps | Buy vol: 1111 | QF: 56.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona
#     → Asghatil             (sec 0.8) | 8.00 jumps | Buy vol: 2222 | QF: 35.00 | LS: Rahadalon, Nakah, Hasateem, Gomati
#     → Chidah               (sec 0.5) | 9.00 jumps | Buy vol: 2222 | QF: 50.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona, Onsooh
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Naeel (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 28.00 (from Jita) | Lowsec jumps: 12 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Sosala, Kamela]
#   Quiet: 13.50  (s+pk: 0.0, j: 27.0, NPCk: 27.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 3.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Laddiaha             (sec 0.7) | 1.00 jumps | QF: 66.00  (s+pk: 0.0, j: 23.0, NPCk: 43.0)
#     ↳ Uadelah              (sec 0.8) | 2.00 jumps | QF: 370.00  (s+pk: 0.0, j: 320.0, NPCk: 50.0)
#   Closest Triglavian Buyer Systems:
#     → Asabona              (sec 0.3) | 9.00 jumps | Buy vol: 1111 | QF: 56.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona
#     → Esteban              (sec 0.6) | 9.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#     → Goram                (sec 0.6) | 9.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Nehkiah (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 15.90  (s+pk: 0.0, j: 32.0, NPCk: 31.0)
#   Close Alt Sec Systems:
#     ↳ Siyi                 (sec 0.5) | 1.00 jumps | QF: 148.00  (s+pk: 0.0, j: 10.0, NPCk: 138.0)
#     ↳ Abai                 (sec 0.7) | 1.00 jumps | QF: 222.00  (s+pk: 0.0, j: 56.0, NPCk: 166.0)
#     ↳ Baviasi              (sec 0.8) | 2.00 jumps | QF: 259.00  (s+pk: 2.0, j: 66.0, NPCk: 191.0)
#   Closest Triglavian Buyer Systems:
#     → Pimebeka             (sec 0.7) | 3.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 3.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 4.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Iro (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 16.20  (s+pk: 0.0, j: 21.0, NPCk: 78.0)
#   Close Alt Sec Systems:
#     ↳ Siyi                 (sec 0.5) | 2.00 jumps | QF: 148.00  (s+pk: 0.0, j: 10.0, NPCk: 138.0)
#     ↳ Abai                 (sec 0.7) | 1.00 jumps | QF: 222.00  (s+pk: 0.0, j: 56.0, NPCk: 166.0)
#     ↳ Baviasi              (sec 0.8) | 2.00 jumps | QF: 259.00  (s+pk: 2.0, j: 66.0, NPCk: 191.0)
#   Closest Triglavian Buyer Systems:
#     → Pimebeka             (sec 0.7) | 3.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 3.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 4.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Atier (Sinq Laison) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 18.00 (from Jita) | Lowsec jumps: 2 [Olettiers, Balle]
#   Quiet: 17.80  (s+pk: 0.0, j: 32.0, NPCk: 50.0)
#   Close Alt Sec Systems:
#     ↳ Bawilan              (sec 0.5) | 1.00 jumps | QF: 302.00  (s+pk: 0.0, j: 50.0, NPCk: 252.0)
#     ↳ Brapelille           (sec 0.7) | 2.00 jumps | QF: 488.00  (s+pk: 0.0, j: 167.0, NPCk: 321.0)
#     ↳ Fricoure             (sec 0.8) | 3.00 jumps | QF: 265.00  (s+pk: 0.0, j: 118.0, NPCk: 147.0)
#   Closest Triglavian Buyer Systems:
#     → Groothese            (sec 0.3) | 9.00 jumps | Buy vol: 1111 | QF: 53.00 | LS: Elarel, Groothese
#     → Pakhshi              (sec 0.8) | 9.00 jumps | Buy vol: 1111 | QF: 927.00 | LS: Balle
#     → Yulai                (sec 1.0) | 9.00 jumps | Buy vol: 39999 | QF: 233.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Hahda (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 17.80  (s+pk: 0.0, j: 11.0, NPCk: 134.0)
#   Close Alt Sec Systems:
#     ↳ Afivad               (sec 0.5) | 1.00 jumps | QF: 227.00  (s+pk: 0.0, j: 23.0, NPCk: 204.0)
#     ↳ Anila                (sec 0.7) | 1.00 jumps | QF: 111.00  (s+pk: 0.0, j: 67.0, NPCk: 44.0)
#     ↳ Yeeramoun            (sec 0.8) | 2.00 jumps | QF: 115.00  (s+pk: 0.0, j: 47.0, NPCk: 68.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 7.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 8.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Tividu               (sec 0.6) | 8.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Miah (Kador) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 22.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 18.90  (s+pk: 0.0, j: 42.0, NPCk: 21.0)
#   Close Alt Sec Systems:
#     ↳ Yarebap              (sec 0.5) | 1.00 jumps | QF: 65.00  (s+pk: 0.0, j: 18.0, NPCk: 47.0)
#     ↳ Gensela              (sec 0.7) | 1.00 jumps | QF: 524.00  (s+pk: 0.0, j: 269.0, NPCk: 255.0)
#     ↳ Akhragan             (sec 0.8) | 3.00 jumps | QF: 311.00  (s+pk: 0.0, j: 214.0, NPCk: 97.0)
#   Closest Triglavian Buyer Systems:
#     → Tarta                (sec 0.5) | 6.00 jumps | Buy vol: 2222 | QF: 293.00 | LS: Cleyd, Vecamia, Tarta
#     → Tash-Murkon Prime    (sec 0.8) | 6.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 7.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Jurlesel (Everyshore) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 14.00 (from Jita) | Lowsec jumps: 1 [Olettiers]
#   Quiet: 19.20  (s+pk: 0.0, j: 44.0, NPCk: 16.0)
#   Close Alt Sec Systems:
#     ↳ Junsoraert           (sec 0.5) | 1.00 jumps | QF: 265.00  (s+pk: 0.0, j: 57.0, NPCk: 208.0)
#     ↳ Aice                 (sec 0.7) | 1.00 jumps | QF: 282.00  (s+pk: 0.0, j: 56.0, NPCk: 226.0)
#     ↳ Laic                 (sec 0.8) | 3.00 jumps | QF: 182.00  (s+pk: 0.0, j: 25.0, NPCk: 157.0)
#   Closest Triglavian Buyer Systems:
#     → Pakhshi              (sec 0.8) | 4.00 jumps | Buy vol: 1111 | QF: 927.00 | LS: None
#     → Groothese            (sec 0.3) | 5.00 jumps | Buy vol: 1111 | QF: 53.00 | LS: Elarel, Groothese
#     → Tar                  (sec 0.8) | 5.00 jumps | Buy vol: 33333 | QF: 944.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Ongund (Metropolis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 17.00 (from Jita) | Lowsec jumps: 2 [Olettiers, Balle]
#   Quiet: 20.50  (s+pk: 0.0, j: 37.0, NPCk: 57.0)
#   Close Alt Sec Systems:
#     ↳ Uttindar             (sec 0.5) | 2.00 jumps | QF: 1011.00  (s+pk: 0.0, j: 648.0, NPCk: 363.0)
#     ↳ Eust                 (sec 0.7) | 1.00 jumps | QF: 227.00  (s+pk: 0.0, j: 29.0, NPCk: 198.0)
#     ↳ Hek                  (sec 0.8) | 3.00 jumps | QF: 1988.00  (s+pk: 3.0, j: 1026.0, NPCk: 959.0)
#   Closest Triglavian Buyer Systems:
#     → Evati                (sec 0.2) | 4.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Hagilur, Anher, Evati
#     → Lasleinur            (sec 0.2) | 5.00 jumps | Buy vol: 2222 | QF: 232.00 | LS: Hagilur, Anher, Evati, Lasleinur
#     → Todifrauan           (sec 0.1) | 5.00 jumps | Buy vol: 2222 | QF: 74.00 | LS: Hagilur, Anher, Evati, Todifrauan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Ahrosseas (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 20.90  (s+pk: 0.0, j: 19.0, NPCk: 133.0)
#   Close Alt Sec Systems:
#     ↳ Anjedin              (sec 0.5) | 3.00 jumps | QF: 156.00  (s+pk: 0.0, j: 111.0, NPCk: 45.0)
#     ↳ Nafomeh              (sec 0.7) | 2.00 jumps | QF: 121.00  (s+pk: 0.0, j: 55.0, NPCk: 66.0)
#     ↳ Armala               (sec 0.8) | 3.00 jumps | QF: 147.00  (s+pk: 0.0, j: 49.0, NPCk: 98.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 1.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 2.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Pimebeka             (sec 0.7) | 4.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Arera (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 26.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 21.90  (s+pk: 0.0, j: 36.0, NPCk: 75.0)
#   Close Alt Sec Systems:
#     ↳ Ahala                (sec 0.5) | 1.00 jumps | QF: 24.00  (s+pk: 0.0, j: 5.0, NPCk: 19.0)
#     ↳ Knophtikoo           (sec 0.7) | 1.00 jumps | QF: 100.00  (s+pk: 0.0, j: 8.0, NPCk: 92.0)
#     ↳ Akhragan             (sec 0.8) | 3.00 jumps | QF: 311.00  (s+pk: 0.0, j: 214.0, NPCk: 97.0)
#   Closest Triglavian Buyer Systems:
#     → Mamenkhanar          (sec 0.7) | 2.00 jumps | Buy vol: 2222 | QF: 68.00 | LS: None
#     → Neziel               (sec 0.4) | 2.00 jumps | Buy vol: 2222 | QF: 90.00 | LS: Neziel
#     → Ruchy                (sec 0.4) | 3.00 jumps | Buy vol: 2222 | QF: 3.00 | LS: Neziel, Ruchy
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Seiradih (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 27.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 23.60  (s+pk: 0.0, j: 42.0, NPCk: 68.0)
#   Close Alt Sec Systems:
#     ↳ Hai                  (sec 0.5) | 1.00 jumps | QF: 6.00  (s+pk: 0.0, j: 6.0, NPCk: 0.0)
#     ↳ Mamenkhanar          (sec 0.7) | 1.00 jumps | QF: 68.00  (s+pk: 0.0, j: 60.0, NPCk: 8.0)
#     ↳ Toshabia             (sec 0.8) | 2.00 jumps | QF: 229.00  (s+pk: 0.0, j: 113.0, NPCk: 116.0)
#   Closest Triglavian Buyer Systems:
#     → Mamenkhanar          (sec 0.7) | 1.00 jumps | Buy vol: 2222 | QF: 68.00 | LS: None
#     → Neziel               (sec 0.4) | 1.00 jumps | Buy vol: 2222 | QF: 90.00 | LS: Neziel
#     → Ruchy                (sec 0.4) | 2.00 jumps | Buy vol: 2222 | QF: 3.00 | LS: Neziel, Ruchy
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Atoosh (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 24.00  (s+pk: 0.0, j: 29.0, NPCk: 124.0)
#   Close Alt Sec Systems:
#     ↳ Mimen                (sec 0.5) | 2.00 jumps | QF: 50.00  (s+pk: 0.0, j: 14.0, NPCk: 36.0)
#     ↳ Sinid                (sec 0.7) | 1.00 jumps | QF: 101.00  (s+pk: 0.0, j: 21.0, NPCk: 80.0)
#     ↳ Mani                 (sec 0.8) | 2.00 jumps | QF: 265.00  (s+pk: 0.0, j: 55.0, NPCk: 210.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 3.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Asesamy              (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 121.00 | LS: Hoona
#     → Hilaban              (sec 0.9) | 4.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Hakshma (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 11 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Gammel]
#   Quiet: 24.20  (s+pk: 1.0, j: 32.0, NPCk: 109.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 2.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Laddiaha             (sec 0.7) | 2.00 jumps | QF: 66.00  (s+pk: 0.0, j: 23.0, NPCk: 43.0)
#     ↳ Hati                 (sec 0.8) | 2.00 jumps | QF: 407.00  (s+pk: 0.0, j: 385.0, NPCk: 22.0)
#   Closest Triglavian Buyer Systems:
#     → Asabona              (sec 0.3) | 8.00 jumps | Buy vol: 1111 | QF: 56.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona
#     → Esteban              (sec 0.6) | 8.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#     → Goram                (sec 0.6) | 8.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Sacalan (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 24.60  (s+pk: 0.0, j: 29.0, NPCk: 130.0)
#   Close Alt Sec Systems:
#     ↳ Mimen                (sec 0.5) | 1.00 jumps | QF: 50.00  (s+pk: 0.0, j: 14.0, NPCk: 36.0)
#     ↳ Abai                 (sec 0.7) | 2.00 jumps | QF: 222.00  (s+pk: 0.0, j: 56.0, NPCk: 166.0)
#     ↳ Baviasi              (sec 0.8) | 3.00 jumps | QF: 259.00  (s+pk: 2.0, j: 66.0, NPCk: 191.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 3.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Asesamy              (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 121.00 | LS: Hoona
#     → Goram                (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Goram (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 25.00  (s+pk: 0.0, j: 48.0, NPCk: 58.0)
#   Close Alt Sec Systems:
#     ↳ Anjedin              (sec 0.5) | 2.00 jumps | QF: 156.00  (s+pk: 0.0, j: 111.0, NPCk: 45.0)
#     ↳ Pimebeka             (sec 0.7) | 3.00 jumps | QF: 430.00  (s+pk: 0.0, j: 150.0, NPCk: 280.0)
#     ↳ Armala               (sec 0.8) | 2.00 jumps | QF: 147.00  (s+pk: 0.0, j: 49.0, NPCk: 98.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 0.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 1.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Pimebeka             (sec 0.7) | 3.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Nakatre (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 11 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Gammel]
#   Quiet: 26.10  (s+pk: 0.0, j: 48.0, NPCk: 69.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 1.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Laddiaha             (sec 0.7) | 1.00 jumps | QF: 66.00  (s+pk: 0.0, j: 23.0, NPCk: 43.0)
#     ↳ Uadelah              (sec 0.8) | 2.00 jumps | QF: 370.00  (s+pk: 0.0, j: 320.0, NPCk: 50.0)
#   Closest Triglavian Buyer Systems:
#     → Asabona              (sec 0.3) | 7.00 jumps | Buy vol: 1111 | QF: 56.00 | LS: Rahadalon, Nakah, Hasateem, Gomati, Irshah, Asabona
#     → Asghatil             (sec 0.8) | 8.00 jumps | Buy vol: 2222 | QF: 35.00 | LS: Rahadalon, Nakah, Hasateem, Gomati
#     → Esteban              (sec 0.6) | 8.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Jarzalad (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 27.10  (s+pk: 0.0, j: 59.0, NPCk: 35.0)
#   Close Alt Sec Systems:
#     ↳ Joppaya              (sec 0.5) | 3.00 jumps | QF: 132.00  (s+pk: 0.0, j: 23.0, NPCk: 109.0)
#     ↳ Nafomeh              (sec 0.7) | 1.00 jumps | QF: 121.00  (s+pk: 0.0, j: 55.0, NPCk: 66.0)
#     ↳ Khopa                (sec 0.8) | 2.00 jumps | QF: 427.00  (s+pk: 0.0, j: 108.0, NPCk: 319.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 2.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 3.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Esteban              (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Sehmosh (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 27.30  (s+pk: 0.0, j: 45.0, NPCk: 93.0)
#   Close Alt Sec Systems:
#     ↳ Ivih                 (sec 0.5) | 1.00 jumps | QF: 245.00  (s+pk: 0.0, j: 45.0, NPCk: 200.0)
#     ↳ Pimebeka             (sec 0.7) | 3.00 jumps | QF: 430.00  (s+pk: 0.0, j: 150.0, NPCk: 280.0)
#     ↳ Mani                 (sec 0.8) | 2.00 jumps | QF: 265.00  (s+pk: 0.0, j: 55.0, NPCk: 210.0)
#   Closest Triglavian Buyer Systems:
#     → Pimebeka             (sec 0.7) | 3.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#     → Tividu               (sec 0.6) | 3.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Goram                (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Oerse (Solitude) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 15 [Olettiers, Mesybier, PF-346, FD-MLJ, X-BV98, Poitot, F67E-Q, MHC-R3, 6E-578, ZVN5-H, 8-JYPM, M2-CF1, 97X-CH, Y9G-KS, Pertnineere]
#   Quiet: 28.20  (s+pk: 0.0, j: 43.0, NPCk: 110.0)
#   Close Alt Sec Systems:
#     ↳ Boystin              (sec 0.5) | 1.00 jumps | QF: 94.00  (s+pk: 0.0, j: 33.0, NPCk: 61.0)
#     ↳ Maire                (sec 0.7) | 1.00 jumps | QF: 151.00  (s+pk: 0.0, j: 30.0, NPCk: 121.0)
#     ↳ Yvaeroure            (sec 0.8) | 3.00 jumps | QF: 122.00  (s+pk: 0.0, j: 20.0, NPCk: 102.0)
#   Closest Triglavian Buyer Systems:
#     → Reblier              (sec 0.4) | 9.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, EZA-FM, 6-CZ49, Reblier
#     → Sortet               (sec 0.8) | 14.00 jumps | Buy vol: 2222 | QF: 370.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, EZA-FM, 6-CZ49, Reblier
#     → Aulbres              (sec 0.1) | 15.00 jumps | Buy vol: 5555 | QF: 190.00 | LS: Pertnineere, Y9G-KS, 97X-CH, M2-CF1, 8-JYPM, ZVN5-H, 6E-578, MHC-R3, Harroule, Ostingele, Alperaute, Aunsou, Gare, Aulbres
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Foves (Sinq Laison) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 16.00 (from Jita) | Lowsec jumps: 1 [Olettiers]
#   Quiet: 28.50  (s+pk: 0.0, j: 39.0, NPCk: 129.0)
#   Close Alt Sec Systems:
#     ↳ Pulin                (sec 0.5) | 1.00 jumps | QF: 344.00  (s+pk: 0.0, j: 114.0, NPCk: 230.0)
#     ↳ Chelien              (sec 0.7) | 1.00 jumps | QF: 204.00  (s+pk: 0.0, j: 64.0, NPCk: 140.0)
#     ↳ Alles                (sec 0.8) | 1.00 jumps | QF: 268.00  (s+pk: 0.0, j: 53.0, NPCk: 215.0)
#   Closest Triglavian Buyer Systems:
#     → Groothese            (sec 0.3) | 6.00 jumps | Buy vol: 1111 | QF: 53.00 | LS: Elarel, Groothese
#     → Olide                (sec 0.7) | 7.00 jumps | Buy vol: 3333 | QF: 61.00 | LS: Elarel, Groothese
#     → Yulai                (sec 1.0) | 7.00 jumps | Buy vol: 39999 | QF: 233.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Brybier (Sinq Laison) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 17.00 (from Jita) | Lowsec jumps: 2 [Olettiers, Balle]
#   Quiet: 28.60  (s+pk: 0.0, j: 22.0, NPCk: 198.0)
#   Close Alt Sec Systems:
#     ↳ Bawilan              (sec 0.5) | 2.00 jumps | QF: 302.00  (s+pk: 0.0, j: 50.0, NPCk: 252.0)
#     ↳ Brapelille           (sec 0.7) | 1.00 jumps | QF: 488.00  (s+pk: 0.0, j: 167.0, NPCk: 321.0)
#     ↳ Fricoure             (sec 0.8) | 2.00 jumps | QF: 265.00  (s+pk: 0.0, j: 118.0, NPCk: 147.0)
#   Closest Triglavian Buyer Systems:
#     → Groothese            (sec 0.3) | 8.00 jumps | Buy vol: 1111 | QF: 53.00 | LS: Elarel, Groothese
#     → Pakhshi              (sec 0.8) | 8.00 jumps | Buy vol: 1111 | QF: 927.00 | LS: Balle
#     → Yulai                (sec 1.0) | 8.00 jumps | Buy vol: 39999 | QF: 233.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Archavoinet (Placid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 17.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Mesybier, Oulley, Aubenall]
#   Quiet: 28.70  (s+pk: 0.0, j: 13.0, NPCk: 235.0)
#   Close Alt Sec Systems:
#     ↳ Vivanier             (sec 0.5) | 2.00 jumps | QF: 90.00  (s+pk: 0.0, j: 12.0, NPCk: 78.0)
#     ↳ Algasienan           (sec 0.7) | 1.00 jumps | QF: 133.00  (s+pk: 0.0, j: 12.0, NPCk: 121.0)
#     ↳ Osmallanais          (sec 0.8) | 2.00 jumps | QF: 117.00  (s+pk: 0.0, j: 8.0, NPCk: 109.0)
#   Closest Triglavian Buyer Systems:
#     → Yashunen             (sec 1.0) | 7.00 jumps | Buy vol: 2222 | QF: 421.00 | LS: Aubenall, Oulley, Mesybier
#     → Hatakani             (sec 0.9) | 8.00 jumps | Buy vol: 2222 | QF: 2243.00 | LS: Aubenall, Oulley, Mesybier
#     → Kemerk               (sec 0.8) | 8.00 jumps | Buy vol: 1111 | QF: 180.00 | LS: Aubenall, Oulley, Mesybier, Pemene
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Kuoka (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 5.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 29.00  (s+pk: 0.0, j: 25.0, NPCk: 190.0)
#   Close Alt Sec Systems:
#     ↳ Sotrentaira          (sec 0.5) | 3.00 jumps | QF: 417.00  (s+pk: 0.0, j: 94.0, NPCk: 323.0)
#     ↳ Tsukuras             (sec 0.7) | 2.00 jumps | QF: 210.00  (s+pk: 0.0, j: 21.0, NPCk: 189.0)
#     ↳ Autama               (sec 0.8) | 3.00 jumps | QF: 309.00  (s+pk: 0.0, j: 45.0, NPCk: 264.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 5.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 6.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 7.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Fluekele (Sinq Laison) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 14.00 (from Jita) | Lowsec jumps: 1 [Olettiers]
#   Quiet: 29.10  (s+pk: 0.0, j: 30.0, NPCk: 171.0)
#   Close Alt Sec Systems:
#     ↳ Alsottobier          (sec 0.5) | 1.00 jumps | QF: 224.00  (s+pk: 0.0, j: 12.0, NPCk: 212.0)
#     ↳ Abenync              (sec 0.7) | 3.00 jumps | QF: 363.00  (s+pk: 0.0, j: 67.0, NPCk: 296.0)
#     ↳ Doussivitte          (sec 0.8) | 2.00 jumps | QF: 974.00  (s+pk: 0.0, j: 146.0, NPCk: 828.0)
#   Closest Triglavian Buyer Systems:
#     → Pakhshi              (sec 0.8) | 7.00 jumps | Buy vol: 1111 | QF: 927.00 | LS: None
#     → Tennen               (sec 0.9) | 7.00 jumps | Buy vol: 1111 | QF: 358.00 | LS: None
#     → Evati                (sec 0.2) | 8.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Hagilur, Anher, Evati
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Earwik (Metropolis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 18.00 (from Jita) | Lowsec jumps: 7 [Akora, Messoya, Tasti, Otosela, Uemon, Fuskunen, Ofage]
#   Quiet: 30.20  (s+pk: 0.0, j: 63.0, NPCk: 50.0)
#   Close Alt Sec Systems:
#     ↳ Finanar              (sec 0.5) | 1.00 jumps | QF: 29.00  (s+pk: 0.0, j: 18.0, NPCk: 11.0)
#     ↳ Moselgi              (sec 0.7) | 1.00 jumps | QF: 57.00  (s+pk: 0.0, j: 34.0, NPCk: 23.0)
#     ↳ Eram                 (sec 0.8) | 2.00 jumps | QF: 396.00  (s+pk: 1.0, j: 264.0, NPCk: 131.0)
#   Closest Triglavian Buyer Systems:
#     → Todifrauan           (sec 0.1) | 7.00 jumps | Buy vol: 2222 | QF: 74.00 | LS: Ofage, Fuskunen, Uemon, Otosela, Akkio, Todifrauan
#     → Evati                (sec 0.2) | 8.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Ofage, Fuskunen, Uemon, Otosela, Akkio, Todifrauan, Evati
#     → Istodard             (sec 0.3) | 8.00 jumps | Buy vol: 2222 | QF: 190.00 | LS: Oddelulf, Istodard
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Tendhyes (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 30.30  (s+pk: 0.0, j: 54.0, NPCk: 87.0)
#   Close Alt Sec Systems:
#     ↳ Anjedin              (sec 0.5) | 1.00 jumps | QF: 156.00  (s+pk: 0.0, j: 111.0, NPCk: 45.0)
#     ↳ Pimebeka             (sec 0.7) | 2.00 jumps | QF: 430.00  (s+pk: 0.0, j: 150.0, NPCk: 280.0)
#     ↳ Armala               (sec 0.8) | 3.00 jumps | QF: 147.00  (s+pk: 0.0, j: 49.0, NPCk: 98.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 1.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 1.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Pimebeka             (sec 0.7) | 2.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Riramia (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 30.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 31.60  (s+pk: 0.0, j: 24.0, NPCk: 220.0)
#   Close Alt Sec Systems:
#     ↳ Joppaya              (sec 0.5) | 1.00 jumps | QF: 132.00  (s+pk: 0.0, j: 23.0, NPCk: 109.0)
#     ↳ Pimsu                (sec 0.7) | 1.00 jumps | QF: 133.00  (s+pk: 0.0, j: 36.0, NPCk: 97.0)
#     ↳ Elmed                (sec 0.8) | 2.00 jumps | QF: 16.00  (s+pk: 0.0, j: 5.0, NPCk: 11.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 5.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Esteban              (sec 0.6) | 6.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Riavayed (Devoid) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 28.00 (from Jita) | Lowsec jumps: 11 [Olettiers, Audaerne, Avenod, Aset, Isbrabata, Kurniainen, Oyonata, Sahtogas, Tannakan, Anka, Gammel]
#   Quiet: 34.30  (s+pk: 0.0, j: 56.0, NPCk: 119.0)
#   Close Alt Sec Systems:
#     ↳ Mendori              (sec 0.5) | 2.00 jumps | QF: 92.00  (s+pk: 0.0, j: 40.0, NPCk: 52.0)
#     ↳ Laddiaha             (sec 0.7) | 2.00 jumps | QF: 66.00  (s+pk: 0.0, j: 23.0, NPCk: 43.0)
#     ↳ Hati                 (sec 0.8) | 1.00 jumps | QF: 407.00  (s+pk: 0.0, j: 385.0, NPCk: 22.0)
#   Closest Triglavian Buyer Systems:
#     → Esteban              (sec 0.6) | 7.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#     → Goram                (sec 0.6) | 7.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Sahdil               (sec 0.7) | 7.00 jumps | Buy vol: 2222 | QF: 90.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Sharhelund (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 35.30  (s+pk: 0.0, j: 41.0, NPCk: 189.0)
#   Close Alt Sec Systems:
#     ↳ Zaimeth              (sec 0.5) | 1.00 jumps | QF: 70.00  (s+pk: 0.0, j: 26.0, NPCk: 44.0)
#     ↳ Ekid                 (sec 0.7) | 2.00 jumps | QF: 74.00  (s+pk: 0.0, j: 17.0, NPCk: 57.0)
#     ↳ Youl                 (sec 0.8) | 1.00 jumps | QF: 159.00  (s+pk: 0.0, j: 86.0, NPCk: 73.0)
#   Closest Triglavian Buyer Systems:
#     → Sahdil               (sec 0.7) | 6.00 jumps | Buy vol: 2222 | QF: 90.00 | LS: None
#     → Esteban              (sec 0.6) | 7.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#     → Tash-Murkon Prime    (sec 0.8) | 7.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Erenta (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 4.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 36.00  (s+pk: 2.0, j: 35.0, NPCk: 210.0)
#   Close Alt Sec Systems:
#     ↳ Sotrentaira          (sec 0.5) | 2.00 jumps | QF: 417.00  (s+pk: 0.0, j: 94.0, NPCk: 323.0)
#     ↳ Ouranienen           (sec 0.7) | 2.00 jumps | QF: 343.00  (s+pk: 0.0, j: 58.0, NPCk: 285.0)
#     ↳ Sobaseki             (sec 0.8) | 3.00 jumps | QF: 2291.00  (s+pk: 2.0, j: 1856.0, NPCk: 433.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 4.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 5.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 6.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Girani-Fa (Genesis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 17.00 (from Jita) | Lowsec jumps: 2 [Olettiers, Tarta]
#   Quiet: 37.20  (s+pk: 0.0, j: 81.0, NPCk: 48.0)
#   Close Alt Sec Systems:
#     ↳ Nasreri              (sec 0.5) | 1.00 jumps | QF: 148.00  (s+pk: 0.0, j: 113.0, NPCk: 35.0)
#     ↳ Aydoteaux            (sec 0.7) | 1.00 jumps | QF: 217.00  (s+pk: 0.0, j: 95.0, NPCk: 122.0)
#     ↳ Manarq               (sec 0.8) | 3.00 jumps | QF: 1298.00  (s+pk: 0.0, j: 876.0, NPCk: 422.0)
#   Closest Triglavian Buyer Systems:
#     → Tarta                (sec 0.5) | 1.00 jumps | Buy vol: 2222 | QF: 293.00 | LS: Tarta
#     → Tekaima              (sec 0.6) | 2.00 jumps | Buy vol: 2222 | QF: 280.00 | LS: Tarta
#     → Tar                  (sec 0.8) | 3.00 jumps | Buy vol: 33333 | QF: 944.00 | LS: Tarta
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Aldagolf (Metropolis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 19.00 (from Jita) | Lowsec jumps: 7 [Akora, Messoya, Tasti, Otosela, Uemon, Fuskunen, Ofage]
#   Quiet: 38.40  (s+pk: 0.0, j: 70.0, NPCk: 104.0)
#   Close Alt Sec Systems:
#     ↳ Finanar              (sec 0.5) | 2.00 jumps | QF: 29.00  (s+pk: 0.0, j: 18.0, NPCk: 11.0)
#     ↳ Moselgi              (sec 0.7) | 2.00 jumps | QF: 57.00  (s+pk: 0.0, j: 34.0, NPCk: 23.0)
#     ↳ Eram                 (sec 0.8) | 1.00 jumps | QF: 396.00  (s+pk: 1.0, j: 264.0, NPCk: 131.0)
#   Closest Triglavian Buyer Systems:
#     → Istodard             (sec 0.3) | 7.00 jumps | Buy vol: 2222 | QF: 190.00 | LS: Oddelulf, Istodard
#     → Stirht               (sec 0.9) | 7.00 jumps | Buy vol: 1111 | QF: 213.00 | LS: None
#     → Altbrard             (sec 0.3) | 8.00 jumps | Buy vol: 1111 | QF: 217.00 | LS: Oddelulf, Istodard, Altbrard
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Uanim (Kador) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 29.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 38.40  (s+pk: 0.0, j: 22.0, NPCk: 296.0)
#   Close Alt Sec Systems:
#     ↳ Joppaya              (sec 0.5) | 3.00 jumps | QF: 132.00  (s+pk: 0.0, j: 23.0, NPCk: 109.0)
#     ↳ Pimsu                (sec 0.7) | 1.00 jumps | QF: 133.00  (s+pk: 0.0, j: 36.0, NPCk: 97.0)
#     ↳ Elmed                (sec 0.8) | 2.00 jumps | QF: 16.00  (s+pk: 0.0, j: 5.0, NPCk: 11.0)
#   Closest Triglavian Buyer Systems:
#     → Goram                (sec 0.6) | 4.00 jumps | Buy vol: 2222 | QF: 106.00 | LS: None
#     → Tividu               (sec 0.6) | 5.00 jumps | Buy vol: 4444 | QF: 60.00 | LS: None
#     → Esteban              (sec 0.6) | 6.00 jumps | Buy vol: 2222 | QF: 25.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Sukirah (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 26.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 41.10  (s+pk: 0.0, j: 17.0, NPCk: 343.0)
#   Close Alt Sec Systems:
#     ↳ Ahala                (sec 0.5) | 3.00 jumps | QF: 24.00  (s+pk: 0.0, j: 5.0, NPCk: 19.0)
#     ↳ Mikhir               (sec 0.7) | 2.00 jumps | QF: 200.00  (s+pk: 1.0, j: 75.0, NPCk: 124.0)
#     ↳ Akhragan             (sec 0.8) | 3.00 jumps | QF: 311.00  (s+pk: 0.0, j: 214.0, NPCk: 97.0)
#   Closest Triglavian Buyer Systems:
#     → Mamenkhanar          (sec 0.7) | 4.00 jumps | Buy vol: 2222 | QF: 68.00 | LS: None
#     → Neziel               (sec 0.4) | 4.00 jumps | Buy vol: 2222 | QF: 90.00 | LS: Neziel
#     → Rannoze              (sec 0.4) | 5.00 jumps | Buy vol: 2222 | QF: 19.00 | LS: Shuria, Narai, Fensi, Rannoze
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Thashkarai (Tash-Murkon) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 28.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 42.40  (s+pk: 0.0, j: 49.0, NPCk: 228.0)
#   Close Alt Sec Systems:
#     ↳ Mimen                (sec 0.5) | 2.00 jumps | QF: 50.00  (s+pk: 0.0, j: 14.0, NPCk: 36.0)
#     ↳ Abai                 (sec 0.7) | 1.00 jumps | QF: 222.00  (s+pk: 0.0, j: 56.0, NPCk: 166.0)
#     ↳ Baviasi              (sec 0.8) | 2.00 jumps | QF: 259.00  (s+pk: 2.0, j: 66.0, NPCk: 191.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 2.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 3.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#     → Pimebeka             (sec 0.7) | 3.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Wirdalen (Metropolis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 22.00 (from Jita) | Lowsec jumps: 9 [Akora, Messoya, Tasti, Otosela, Uemon, Fuskunen, Ofage, Anstard, Erstet]
#   Quiet: 42.90  (s+pk: 0.0, j: 71.0, NPCk: 145.0)
#   Close Alt Sec Systems:
#     ↳ Nein                 (sec 0.5) | 1.00 jumps | QF: 92.00  (s+pk: 0.0, j: 52.0, NPCk: 40.0)
#     ↳ Eygfe                (sec 0.7) | 1.00 jumps | QF: 209.00  (s+pk: 0.0, j: 153.0, NPCk: 56.0)
#     ↳ Altrinur             (sec 0.8) | 2.00 jumps | QF: 517.00  (s+pk: 0.0, j: 309.0, NPCk: 208.0)
#   Closest Triglavian Buyer Systems:
#     → Evati                (sec 0.2) | 10.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Hagilur, Anher, Evati
#     → Istodard             (sec 0.3) | 10.00 jumps | Buy vol: 2222 | QF: 190.00 | LS: Oddelulf, Istodard
#     → Altbrard             (sec 0.3) | 11.00 jumps | Buy vol: 1111 | QF: 217.00 | LS: Oddelulf, Istodard, Altbrard
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Bashakru (Domain) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 25.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 46.20  (s+pk: 0.0, j: 86.0, NPCk: 118.0)
#   Close Alt Sec Systems:
#     ↳ Ahala                (sec 0.5) | 2.00 jumps | QF: 24.00  (s+pk: 0.0, j: 5.0, NPCk: 19.0)
# ...
#   Quiet: 91.40  (s+pk: 0.0, j: 215.0, NPCk: 54.0)
#   Close Alt Sec Systems:
#     ↳ Lor                  (sec 0.5) | 1.00 jumps | QF: 331.00  (s+pk: 0.0, j: 93.0, NPCk: 238.0)
#     ↳ Gensela              (sec 0.7) | 1.00 jumps | QF: 524.00  (s+pk: 0.0, j: 269.0, NPCk: 255.0)
#     ↳ Akhragan             (sec 0.8) | 3.00 jumps | QF: 311.00  (s+pk: 0.0, j: 214.0, NPCk: 97.0)
#   Closest Triglavian Buyer Systems:
#     → Tarta                (sec 0.5) | 4.00 jumps | Buy vol: 2222 | QF: 293.00 | LS: Cleyd, Vecamia, Tarta
#     → Tekaima              (sec 0.6) | 5.00 jumps | Buy vol: 2222 | QF: 280.00 | LS: Cleyd, Vecamia, Tarta
#     → Tar                  (sec 0.8) | 6.00 jumps | Buy vol: 33333 | QF: 944.00 | LS: Cleyd, Vecamia, Tarta
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Jaschercis (Everyshore) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 15.00 (from Jita) | Lowsec jumps: 1 [Olettiers]
#   Quiet: 96.50  (s+pk: 0.0, j: 139.0, NPCk: 409.0)
#   Close Alt Sec Systems:
#     ↳ Pulin                (sec 0.5) | 1.00 jumps | QF: 344.00  (s+pk: 0.0, j: 114.0, NPCk: 230.0)
#     ↳ Cherore              (sec 0.7) | 1.00 jumps | QF: 227.00  (s+pk: 0.0, j: 41.0, NPCk: 186.0)
#     ↳ Harerget             (sec 0.8) | 2.00 jumps | QF: 1151.00  (s+pk: 0.0, j: 192.0, NPCk: 959.0)
#   Closest Triglavian Buyer Systems:
#     → Groothese            (sec 0.3) | 4.00 jumps | Buy vol: 1111 | QF: 53.00 | LS: Elarel, Groothese
#     → Olide                (sec 0.7) | 5.00 jumps | Buy vol: 3333 | QF: 61.00 | LS: Elarel, Groothese
#     → Adeel                (sec 0.4) | 6.00 jumps | Buy vol: 1111 | QF: 3.00 | LS: Elarel, Groothese, Adeel
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Huttaken (The Citadel) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 5.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 97.70  (s+pk: 0.0, j: 160.0, NPCk: 337.0)
#   Close Alt Sec Systems:
#     ↳ Waira                (sec 0.5) | 3.00 jumps | QF: 524.00  (s+pk: 0.0, j: 121.0, NPCk: 403.0)
#     ↳ Halaima              (sec 0.7) | 1.00 jumps | QF: 724.00  (s+pk: 2.0, j: 550.0, NPCk: 172.0)
#     ↳ Veisto               (sec 0.8) | 3.00 jumps | QF: 843.00  (s+pk: 0.0, j: 310.0, NPCk: 533.0)
#   Closest Triglavian Buyer Systems:
#     → Hatakani             (sec 0.9) | 5.00 jumps | Buy vol: 2222 | QF: 2243.00 | LS: Enderailen, Kubinen
#     → Iivinen              (sec 0.7) | 5.00 jumps | Buy vol: 1111 | QF: 415.00 | LS: Enderailen, Kubinen
#     → Tennen               (sec 0.9) | 6.00 jumps | Buy vol: 1111 | QF: 358.00 | LS: Enderailen, Kubinen
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Isseras (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 4.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 109.90  (s+pk: 0.0, j: 103.0, NPCk: 687.0)
#   Close Alt Sec Systems:
#     ↳ Piekura              (sec 0.5) | 3.00 jumps | QF: 356.00  (s+pk: 0.0, j: 125.0, NPCk: 231.0)
#     ↳ Aakari               (sec 0.7) | 1.00 jumps | QF: 669.00  (s+pk: 0.0, j: 85.0, NPCk: 584.0)
#     ↳ Ylandoki             (sec 0.8) | 1.00 jumps | QF: 983.00  (s+pk: 0.0, j: 184.0, NPCk: 799.0)
#   Closest Triglavian Buyer Systems:
#     → Jan                  (sec 0.4) | 5.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Aurohunen, Vaajaita, Jan
#     → Vellaine             (sec 0.6) | 5.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 6.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Aurohunen, Vaajaita, Akonoinen, Autaris
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Dresi (Kador) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 22.00 (from Jita) | Lowsec jumps: 4 [Olettiers, Tarta, Vecamia, Cleyd]
#   Quiet: 128.40  (s+pk: 4.0, j: 236.0, NPCk: 320.0)
#   Close Alt Sec Systems:
#     ↳ Ghesis               (sec 0.5) | 3.00 jumps | QF: 196.00  (s+pk: 0.0, j: 93.0, NPCk: 103.0)
#     ↳ Zororzih             (sec 0.7) | 1.00 jumps | QF: 327.00  (s+pk: 0.0, j: 184.0, NPCk: 143.0)
#     ↳ Akhragan             (sec 0.8) | 2.00 jumps | QF: 311.00  (s+pk: 0.0, j: 214.0, NPCk: 97.0)
#   Closest Triglavian Buyer Systems:
#     → Tash-Murkon Prime    (sec 0.8) | 4.00 jumps | Buy vol: 2222 | QF: 782.00 | LS: None
#     → Hilaban              (sec 0.9) | 5.00 jumps | Buy vol: 2222 | QF: 512.00 | LS: None
#     → Pimebeka             (sec 0.7) | 5.00 jumps | Buy vol: 2222 | QF: 430.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Haatomo (The Citadel) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 5.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 143.50  (s+pk: 0.0, j: 265.0, NPCk: 375.0)
#   Close Alt Sec Systems:
#     ↳ Uedama               (sec 0.5) | 1.00 jumps | QF: 1471.00  (s+pk: 1.0, j: 1322.0, NPCk: 148.0)
#     ↳ Suroken              (sec 0.7) | 1.00 jumps | QF: 1201.00  (s+pk: 1.0, j: 551.0, NPCk: 649.0)
#     ↳ Kusomonmon           (sec 0.8) | 2.00 jumps | QF: 1109.00  (s+pk: 0.0, j: 548.0, NPCk: 561.0)
#   Closest Triglavian Buyer Systems:
#     → Hatakani             (sec 0.9) | 3.00 jumps | Buy vol: 2222 | QF: 2243.00 | LS: None
#     → Iivinen              (sec 0.7) | 3.00 jumps | Buy vol: 1111 | QF: 415.00 | LS: None
#     → Tennen               (sec 0.9) | 4.00 jumps | Buy vol: 1111 | QF: 358.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Vellaine (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 3.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 146.90  (s+pk: 0.0, j: 302.0, NPCk: 261.0)
#   Close Alt Sec Systems:
#     ↳ Saatuban             (sec 0.5) | 3.00 jumps | QF: 136.00  (s+pk: 1.0, j: 86.0, NPCk: 49.0)
#     ↳ Alikara              (sec 0.7) | 1.00 jumps | QF: 670.00  (s+pk: 1.0, j: 525.0, NPCk: 144.0)
#     ↳ Aikoro               (sec 0.8) | 2.00 jumps | QF: 322.00  (s+pk: 0.0, j: 94.0, NPCk: 228.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 0.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 1.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 2.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Hageken (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 5.00 (from Jita) | Lowsec jumps: 1 [Akonoinen]
#   Quiet: 165.10  (s+pk: 0.0, j: 275.0, NPCk: 551.0)
#   Close Alt Sec Systems:
#     ↳ Vuorrassi            (sec 0.5) | 1.00 jumps | QF: 594.00  (s+pk: 0.0, j: 211.0, NPCk: 383.0)
#     ↳ Uosusuokko           (sec 0.7) | 1.00 jumps | QF: 938.00  (s+pk: 1.0, j: 241.0, NPCk: 696.0)
#     ↳ Isikemi              (sec 0.8) | 2.00 jumps | QF: 1006.00  (s+pk: 0.0, j: 285.0, NPCk: 721.0)
#   Closest Triglavian Buyer Systems:
#     → Autaris              (sec 0.5) | 2.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Akonoinen, Autaris
#     → Vellaine             (sec 0.6) | 2.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: Akonoinen
#     → Jan                  (sec 0.4) | 3.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Akonoinen, Vaajaita, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Ikao (The Citadel) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 6.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 171.80  (s+pk: 0.0, j: 368.0, NPCk: 246.0)
#   Close Alt Sec Systems:
#     ↳ Uedama               (sec 0.5) | 1.00 jumps | QF: 1471.00  (s+pk: 1.0, j: 1322.0, NPCk: 148.0)
#     ↳ Kamio                (sec 0.7) | 1.00 jumps | QF: 618.00  (s+pk: 0.0, j: 337.0, NPCk: 281.0)
#     ↳ Santola              (sec 0.8) | 1.00 jumps | QF: 385.00  (s+pk: 0.0, j: 47.0, NPCk: 338.0)
#   Closest Triglavian Buyer Systems:
#     → Hatakani             (sec 0.9) | 3.00 jumps | Buy vol: 2222 | QF: 2243.00 | LS: None
#     → Iivinen              (sec 0.7) | 3.00 jumps | Buy vol: 1111 | QF: 415.00 | LS: None
#     → Tennen               (sec 0.9) | 4.00 jumps | Buy vol: 1111 | QF: 358.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Onnamon (Black Rise) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 7.00 (from Jita) | Lowsec jumps: 1 [Litiura]
#   Quiet: 175.40  (s+pk: 11.0, j: 356.0, NPCk: 275.0)
#   Close Alt Sec Systems:
#     ↳ Rohamaa              (sec 0.5) | 1.00 jumps | QF: 242.00  (s+pk: 0.0, j: 67.0, NPCk: 175.0)
#     ↳ Piak                 (sec 0.7) | 1.00 jumps | QF: 713.00  (s+pk: 2.0, j: 450.0, NPCk: 261.0)
#     ↳ Haajinen             (sec 0.8) | 2.00 jumps | QF: 427.00  (s+pk: 0.0, j: 159.0, NPCk: 268.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 7.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: Litiura
#     → Autaris              (sec 0.5) | 8.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Litiura, Autaris
#     → Jan                  (sec 0.4) | 9.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Litiura, Passari, Mara, Dantumi, Aurohunen, Vaajaita, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Avyuh (Genesis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 18.00 (from Jita) | Lowsec jumps: 1 [Olettiers]
#   Quiet: 179.10  (s+pk: 0.0, j: 214.0, NPCk: 935.0)
#   Close Alt Sec Systems:
#     ↳ Sosh                 (sec 0.5) | 2.00 jumps | QF: 395.00  (s+pk: 0.0, j: 160.0, NPCk: 235.0)
#     ↳ Ashokon              (sec 0.7) | 1.00 jumps | QF: 489.00  (s+pk: 0.0, j: 180.0, NPCk: 309.0)
#     ↳ Manarq               (sec 0.8) | 3.00 jumps | QF: 1298.00  (s+pk: 0.0, j: 876.0, NPCk: 422.0)
#   Closest Triglavian Buyer Systems:
#     → Kemerk               (sec 0.8) | 4.00 jumps | Buy vol: 1111 | QF: 180.00 | LS: None
#     → Tar                  (sec 0.8) | 4.00 jumps | Buy vol: 33333 | QF: 944.00 | LS: None
#     → Pakhshi              (sec 0.8) | 5.00 jumps | Buy vol: 1111 | QF: 927.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Inaya (The Forge) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 7.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 217.50  (s+pk: 0.0, j: 194.0, NPCk: 1399.0)
#   Close Alt Sec Systems:
#     ↳ Airaken              (sec 0.5) | 3.00 jumps | QF: 920.00  (s+pk: 2.0, j: 193.0, NPCk: 725.0)
#     ↳ Osmon                (sec 0.7) | 1.00 jumps | QF: 1446.00  (s+pk: 0.0, j: 454.0, NPCk: 992.0)
#     ↳ Nuken                (sec 0.8) | 3.00 jumps | QF: 352.00  (s+pk: 0.0, j: 47.0, NPCk: 305.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 8.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 9.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 10.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Bei (Metropolis) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 16.00 (from Jita) | Lowsec jumps: 2 [Olettiers, Balle]
#   Quiet: 242.20  (s+pk: 2.0, j: 585.0, NPCk: 72.0)
#   Close Alt Sec Systems:
#     ↳ Uttindar             (sec 0.5) | 1.00 jumps | QF: 1011.00  (s+pk: 0.0, j: 648.0, NPCk: 363.0)
#     ↳ Eust                 (sec 0.7) | 2.00 jumps | QF: 227.00  (s+pk: 0.0, j: 29.0, NPCk: 198.0)
#     ↳ Hek                  (sec 0.8) | 2.00 jumps | QF: 1988.00  (s+pk: 3.0, j: 1026.0, NPCk: 959.0)
#   Closest Triglavian Buyer Systems:
#     → Evati                (sec 0.2) | 3.00 jumps | Buy vol: 2222 | QF: 69.00 | LS: Hagilur, Anher, Evati
#     → Lasleinur            (sec 0.2) | 4.00 jumps | Buy vol: 2222 | QF: 232.00 | LS: Hagilur, Anher, Evati, Lasleinur
#     → Todifrauan           (sec 0.1) | 4.00 jumps | Buy vol: 2222 | QF: 74.00 | LS: Hagilur, Anher, Evati, Todifrauan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Uemisaisen (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 3.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 285.30  (s+pk: 0.0, j: 660.0, NPCk: 213.0)
#   Close Alt Sec Systems:
#     ↳ Sotrentaira          (sec 0.5) | 1.00 jumps | QF: 417.00  (s+pk: 0.0, j: 94.0, NPCk: 323.0)
#     ↳ Ouranienen           (sec 0.7) | 1.00 jumps | QF: 343.00  (s+pk: 0.0, j: 58.0, NPCk: 285.0)
#     ↳ Sobaseki             (sec 0.8) | 2.00 jumps | QF: 2291.00  (s+pk: 2.0, j: 1856.0, NPCk: 433.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 3.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 4.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 5.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Korsiki (The Forge) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 7.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 300.10  (s+pk: 0.0, j: 363.0, NPCk: 1549.0)
#   Close Alt Sec Systems:
#     ↳ Airaken              (sec 0.5) | 1.00 jumps | QF: 920.00  (s+pk: 2.0, j: 193.0, NPCk: 725.0)
#     ↳ Osmon                (sec 0.7) | 1.00 jumps | QF: 1446.00  (s+pk: 0.0, j: 454.0, NPCk: 992.0)
#     ↳ Nuken                (sec 0.8) | 1.00 jumps | QF: 352.00  (s+pk: 0.0, j: 47.0, NPCk: 305.0)
#   Closest Triglavian Buyer Systems:
#     → Todifrauan           (sec 0.1) | 8.00 jumps | Buy vol: 2222 | QF: 74.00 | LS: Oijanen, Akora, Messoya, Tasti, Otosela, Akkio, Todifrauan
#     → Vellaine             (sec 0.6) | 8.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 9.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Juunigaishi (The Citadel) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 5.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 377.70  (s+pk: 0.0, j: 864.0, NPCk: 321.0)
#   Close Alt Sec Systems:
#     ↳ Uedama               (sec 0.5) | 1.00 jumps | QF: 1471.00  (s+pk: 1.0, j: 1322.0, NPCk: 148.0)
#     ↳ Suroken              (sec 0.7) | 1.00 jumps | QF: 1201.00  (s+pk: 1.0, j: 551.0, NPCk: 649.0)
#     ↳ Santola              (sec 0.8) | 2.00 jumps | QF: 385.00  (s+pk: 0.0, j: 47.0, NPCk: 338.0)
#   Closest Triglavian Buyer Systems:
#     → Hatakani             (sec 0.9) | 3.00 jumps | Buy vol: 2222 | QF: 2243.00 | LS: None
#     → Iivinen              (sec 0.7) | 3.00 jumps | Buy vol: 1111 | QF: 415.00 | LS: None
#     → Tennen               (sec 0.9) | 4.00 jumps | Buy vol: 1111 | QF: 358.00 | LS: None
#
# ------------------------------------------------------------------------------------------------------------
#
#
# --- Isanamo (Lonetrek) (0.6) System Avoid List used ✓ ---
#   Jumps from start: 2.00 (from Jita) | Lowsec jumps: 0 [None]
#   Quiet: 435.40  (s+pk: 8.0, j: 916.0, NPCk: 650.0)
#   Close Alt Sec Systems:
#     ↳ Saatuban             (sec 0.5) | 1.00 jumps | QF: 136.00  (s+pk: 1.0, j: 86.0, NPCk: 49.0)
#     ↳ Alikara              (sec 0.7) | 1.00 jumps | QF: 670.00  (s+pk: 1.0, j: 525.0, NPCk: 144.0)
#     ↳ Sobaseki             (sec 0.8) | 1.00 jumps | QF: 2291.00  (s+pk: 2.0, j: 1856.0, NPCk: 433.0)
#   Closest Triglavian Buyer Systems:
#     → Vellaine             (sec 0.6) | 2.00 jumps | Buy vol: 1111 | QF: 563.00 | LS: None
#     → Autaris              (sec 0.5) | 3.00 jumps | Buy vol: 3333 | QF: 333.00 | LS: Autaris
#     → Jan                  (sec 0.4) | 4.00 jumps | Buy vol: 1111 | QF: 83.00 | LS: Autaris, Jan
#
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### DED Farming Hub finder

# %%
results = find_ded_farming_bases(
    G,
    target_faction="Caldari",           ### space you want to farm, consider which pirates spawn where
    spawn_radius=15,                    ### Range where escalatations can spawn, I think it is 15 for Guristas 4/10
    close_range=5,                      ### Just for print, to know how busy you surrondings are
    use_avoid_list=True,                
    avoid_multiplier=3.0,               ### Systems on the Avoid List are extra penalized if in range in the algorithm, encouraging distance.  
    quiet_weights=(0.1, 0.3, 0.6),      ### Ship/pod kills, Jumps, NPC Kills, 
    quiet_days=14,                      ### Time period to average player activity data over.
    top_k=20                            ### how many candidates to print. 
)
# Out:
# Evaluating candidates:   0%|          | 0/195 [00:00<?, ?it/s]
# Top 20 candidate systems for DED farming (Caldari):
#
# --- Ukkalen (The Forge) (0.6) — Otsabaira ---
# Score: 304.00
# Quiet Factor: 157.90
# Avg Nearby HS Quietness (≤ 5 jumps): 192.12
# Nearby HS Systems: 11.00
# Nearby LS Systems in range: 29.00
# Avg LS Distance: 12.24
# LS system distance distribution:
#   - 1 at distance 5
#   - 2 at distance 6
#   - 5 at distance 10
#   - 3 at distance 11
#   - 2 at distance 12
#   - 3 at distance 13
#   - 3 at distance 14
#   - 10 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 12.00)
#   - Uedama (Distance: 15.00)
#   - Tama (Distance: 15.00)
#   - Ahbazon (Distance: 15.00)
#
# --- Keikaken (The Forge) (0.7) — Otsabaira ---
# Score: 487.00
# Quiet Factor: 188.40
# Avg Nearby HS Quietness (≤ 5 jumps): 207.83
# Nearby HS Systems: 12.00
# Nearby LS Systems in range: 39.00
# Avg LS Distance: 12.21
# LS system distance distribution:
#   - 1 at distance 4
#   - 2 at distance 5
#   - 5 at distance 9
#   - 3 at distance 10
#   - 2 at distance 11
#   - 3 at distance 12
#   - 3 at distance 13
#   - 10 at distance 14
#   - 10 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 11.00)
#   - Uedama (Distance: 14.00)
#   - Tama (Distance: 14.00)
#   - Ahbazon (Distance: 14.00)
#   - Passari (Distance: 15.00)
#   - Kubinen (Distance: 15.00)
#   - Sivala (Distance: 15.00)
#
# --- Silen (The Forge) (0.5) — Otsabaira ---
# Score: 487.00
# Quiet Factor: 147.60
# Avg Nearby HS Quietness (≤ 5 jumps): 207.83
# Nearby HS Systems: 12.00
# Nearby LS Systems in range: 39.00
# Avg LS Distance: 12.21
# LS system distance distribution:
#   - 1 at distance 4
#   - 2 at distance 5
#   - 5 at distance 9
#   - 3 at distance 10
#   - 2 at distance 11
#   - 3 at distance 12
#   - 3 at distance 13
#   - 10 at distance 14
#   - 10 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 11.00)
#   - Uedama (Distance: 14.00)
#   - Tama (Distance: 14.00)
#   - Ahbazon (Distance: 14.00)
#   - Passari (Distance: 15.00)
#   - Kubinen (Distance: 15.00)
#   - Sivala (Distance: 15.00)
#
# --- Laah (The Citadel) (0.9) — Santenpaa ---
# Score: 623.00
# Quiet Factor: 283.80
# Avg Nearby HS Quietness (≤ 5 jumps): 212.75
# Nearby HS Systems: 8.00
# Nearby LS Systems in range: 59.00
# Avg LS Distance: 13.20
# LS system distance distribution:
#   - 1 at distance 9
#   - 2 at distance 10
#   - 3 at distance 11
#   - 13 at distance 12
#   - 15 at distance 13
#   - 9 at distance 14
#   - 16 at distance 15
# Avoid-list systems (within radius):
#   - Uedama (Distance: 9.00)
#   - Kubinen (Distance: 10.00)
#   - Jita (Distance: 10.00)
#   - Sivala (Distance: 10.00)
#   - Tama (Distance: 10.00)
#   - Passari (Distance: 12.00)
#   - Ahbazon (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Kinakka (Distance: 15.00)
#   - Rancer (Distance: 15.00)
#
# --- Motsu (The Citadel) (0.9) — Santenpaa ---
# Score: 623.00
# Quiet Factor: 191.20
# Avg Nearby HS Quietness (≤ 5 jumps): 212.75
# Nearby HS Systems: 8.00
# Nearby LS Systems in range: 59.00
# Avg LS Distance: 13.20
# LS system distance distribution:
#   - 1 at distance 9
#   - 2 at distance 10
#   - 3 at distance 11
#   - 13 at distance 12
#   - 15 at distance 13
#   - 9 at distance 14
#   - 16 at distance 15
# Avoid-list systems (within radius):
#   - Uedama (Distance: 9.00)
#   - Kubinen (Distance: 10.00)
#   - Jita (Distance: 10.00)
#   - Sivala (Distance: 10.00)
#   - Tama (Distance: 10.00)
#   - Passari (Distance: 12.00)
#   - Ahbazon (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Kinakka (Distance: 15.00)
#   - Rancer (Distance: 15.00)
#
# --- Onuse (The Forge) (0.7) — Otsabaira ---
# Score: 798.00
# Quiet Factor: 212.70
# Avg Nearby HS Quietness (≤ 5 jumps): 229.66
# Nearby HS Systems: 16.00
# Nearby LS Systems in range: 58.00
# Avg LS Distance: 12.45
# LS system distance distribution:
#   - 1 at distance 3
#   - 2 at distance 4
#   - 5 at distance 8
#   - 3 at distance 9
#   - 2 at distance 10
#   - 3 at distance 11
#   - 3 at distance 12
#   - 10 at distance 13
#   - 10 at distance 14
#   - 19 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 10.00)
#   - Uedama (Distance: 13.00)
#   - Tama (Distance: 13.00)
#   - Ahbazon (Distance: 13.00)
#   - Passari (Distance: 14.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Aunenen (Distance: 15.00)
#
# --- Soshin (The Forge) (0.6) — Otsabaira ---
# Score: 798.00
# Quiet Factor: 81.00
# Avg Nearby HS Quietness (≤ 5 jumps): 229.66
# Nearby HS Systems: 16.00
# Nearby LS Systems in range: 58.00
# Avg LS Distance: 12.45
# LS system distance distribution:
#   - 1 at distance 3
#   - 2 at distance 4
#   - 5 at distance 8
#   - 3 at distance 9
#   - 2 at distance 10
#   - 3 at distance 11
#   - 3 at distance 12
#   - 10 at distance 13
#   - 10 at distance 14
#   - 19 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 10.00)
#   - Uedama (Distance: 13.00)
#   - Tama (Distance: 13.00)
#   - Ahbazon (Distance: 13.00)
#   - Passari (Distance: 14.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Aunenen (Distance: 15.00)
#
# --- Hentogaira (The Forge) (0.6) — Etsala ---
# Score: 860.00
# Quiet Factor: 111.30
# Avg Nearby HS Quietness (≤ 5 jumps): 224.43
# Nearby HS Systems: 18.00
# Nearby LS Systems in range: 39.00
# Avg LS Distance: 11.44
# LS system distance distribution:
#   - 1 at distance 1
#   - 2 at distance 2
#   - 3 at distance 6
#   - 1 at distance 7
#   - 1 at distance 8
#   - 4 at distance 9
#   - 2 at distance 10
#   - 1 at distance 11
#   - 1 at distance 12
#   - 3 at distance 13
#   - 10 at distance 14
#   - 10 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 11.00)
#   - Uedama (Distance: 14.00)
#   - Tama (Distance: 14.00)
#   - Ahbazon (Distance: 14.00)
#   - Passari (Distance: 15.00)
#   - Kubinen (Distance: 15.00)
#   - Sivala (Distance: 15.00)
#
# --- Akkilen (The Forge) (0.7) — Otsabaira ---
# Score: 923.00
# Quiet Factor: 222.00
# Avg Nearby HS Quietness (≤ 5 jumps): 239.48
# Nearby HS Systems: 18.00
# Nearby LS Systems in range: 58.00
# Avg LS Distance: 12.28
# LS system distance distribution:
#   - 1 at distance 2
#   - 2 at distance 3
#   - 3 at distance 7
#   - 3 at distance 8
#   - 3 at distance 9
#   - 3 at distance 10
#   - 1 at distance 11
#   - 3 at distance 12
#   - 10 at distance 13
#   - 10 at distance 14
#   - 19 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 10.00)
#   - Uedama (Distance: 13.00)
#   - Tama (Distance: 13.00)
#   - Ahbazon (Distance: 13.00)
#   - Passari (Distance: 14.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Aunenen (Distance: 15.00)
#
# --- Kiainti (The Forge) (0.5) — Etsala ---
# Score: 968.00
# Quiet Factor: 251.70
# Avg Nearby HS Quietness (≤ 5 jumps): 215.24
# Nearby HS Systems: 17.00
# Nearby LS Systems in range: 34.00
# Avg LS Distance: 10.97
# LS system distance distribution:
#   - 2 at distance 1
#   - 1 at distance 2
#   - 3 at distance 5
#   - 1 at distance 6
#   - 1 at distance 7
#   - 2 at distance 8
#   - 3 at distance 10
#   - 1 at distance 11
#   - 1 at distance 12
#   - 2 at distance 13
#   - 9 at distance 14
#   - 8 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 11.00)
#   - Tama (Distance: 14.00)
#   - Ahbazon (Distance: 14.00)
#   - Passari (Distance: 15.00)
#   - Uedama (Distance: 15.00)
#
# --- Saila (The Citadel) (0.9) — Santenpaa ---
# Score: 1091.00
# Quiet Factor: 167.10
# Avg Nearby HS Quietness (≤ 5 jumps): 219.48
# Nearby HS Systems: 10.00
# Nearby LS Systems in range: 75.00
# Avg LS Distance: 12.80
# LS system distance distribution:
#   - 1 at distance 8
#   - 2 at distance 9
#   - 3 at distance 10
#   - 13 at distance 11
#   - 15 at distance 12
#   - 9 at distance 13
#   - 16 at distance 14
#   - 16 at distance 15
# Avoid-list systems (within radius):
#   - Uedama (Distance: 8.00)
#   - Kubinen (Distance: 9.00)
#   - Jita (Distance: 9.00)
#   - Sivala (Distance: 9.00)
#   - Tama (Distance: 9.00)
#   - Passari (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Aunenen (Distance: 12.00)
#   - Kinakka (Distance: 14.00)
#   - Rancer (Distance: 14.00)
#   - Old Man Star (Distance: 15.00)
#
# --- Oichiya (The Citadel) (0.8) — Santenpaa ---
# Score: 1091.00
# Quiet Factor: 233.40
# Avg Nearby HS Quietness (≤ 5 jumps): 219.48
# Nearby HS Systems: 10.00
# Nearby LS Systems in range: 75.00
# Avg LS Distance: 12.80
# LS system distance distribution:
#   - 1 at distance 8
#   - 2 at distance 9
#   - 3 at distance 10
#   - 13 at distance 11
#   - 15 at distance 12
#   - 9 at distance 13
#   - 16 at distance 14
#   - 16 at distance 15
# Avoid-list systems (within radius):
#   - Uedama (Distance: 8.00)
#   - Kubinen (Distance: 9.00)
#   - Jita (Distance: 9.00)
#   - Sivala (Distance: 9.00)
#   - Tama (Distance: 9.00)
#   - Passari (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Aunenen (Distance: 12.00)
#   - Kinakka (Distance: 14.00)
#   - Rancer (Distance: 14.00)
#   - Old Man Star (Distance: 15.00)
#
# --- Vahunomi (The Forge) (0.5) — Okkelen ---
# Score: 1113.00
# Quiet Factor: 203.10
# Avg Nearby HS Quietness (≤ 5 jumps): 414.46
# Nearby HS Systems: 14.00
# Nearby LS Systems in range: 83.00
# Avg LS Distance: 12.54
# LS system distance distribution:
#   - 1 at distance 3
#   - 1 at distance 4
#   - 1 at distance 5
#   - 1 at distance 7
#   - 1 at distance 8
#   - 5 at distance 9
#   - 3 at distance 10
#   - 9 at distance 11
#   - 9 at distance 12
#   - 15 at distance 13
#   - 18 at distance 14
#   - 19 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 8.00)
#   - Tama (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Passari (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Uedama (Distance: 13.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Rancer (Distance: 14.00)
#   - Kinakka (Distance: 15.00)
#
# --- Vattuolen (The Forge) (0.7) — Otsabaira ---
# Score: 1158.00
# Quiet Factor: 241.50
# Avg Nearby HS Quietness (≤ 5 jumps): 237.75
# Nearby HS Systems: 20.00
# Nearby LS Systems in range: 75.00
# Avg LS Distance: 12.39
# LS system distance distribution:
#   - 1 at distance 3
#   - 2 at distance 4
#   - 2 at distance 7
#   - 5 at distance 8
#   - 2 at distance 9
#   - 2 at distance 10
#   - 5 at distance 11
#   - 10 at distance 12
#   - 10 at distance 13
#   - 19 at distance 14
#   - 17 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 9.00)
#   - Uedama (Distance: 12.00)
#   - Tama (Distance: 12.00)
#   - Ahbazon (Distance: 12.00)
#   - Passari (Distance: 13.00)
#   - Kubinen (Distance: 13.00)
#   - Sivala (Distance: 13.00)
#   - Aunenen (Distance: 14.00)
#   - Rancer (Distance: 15.00)
#
# --- Friggi (The Forge) (0.5) — Okkelen ---
# Score: 1360.00
# Quiet Factor: 231.10
# Avg Nearby HS Quietness (≤ 5 jumps): 362.02
# Nearby HS Systems: 19.00
# Nearby LS Systems in range: 83.00
# Avg LS Distance: 12.30
# LS system distance distribution:
#   - 1 at distance 1
#   - 1 at distance 2
#   - 1 at distance 3
#   - 4 at distance 7
#   - 2 at distance 8
#   - 3 at distance 9
#   - 4 at distance 10
#   - 8 at distance 11
#   - 7 at distance 12
#   - 15 at distance 13
#   - 18 at distance 14
#   - 19 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 8.00)
#   - Tama (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Passari (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Uedama (Distance: 13.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Rancer (Distance: 14.00)
#   - Kinakka (Distance: 15.00)
#
# --- Wuos (The Forge) (0.6) — Aulari ---
# Score: 1459.00
# Quiet Factor: 204.30
# Avg Nearby HS Quietness (≤ 5 jumps): 453.83
# Nearby HS Systems: 13.00
# Nearby LS Systems in range: 98.00
# Avg LS Distance: 12.82
# LS system distance distribution:
#   - 1 at distance 5
#   - 1 at distance 6
#   - 3 at distance 7
#   - 2 at distance 8
#   - 2 at distance 9
#   - 3 at distance 10
#   - 10 at distance 11
#   - 9 at distance 12
#   - 21 at distance 13
#   - 21 at distance 14
#   - 25 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 8.00)
#   - Tama (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Passari (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Uedama (Distance: 13.00)
#   - Kubinen (Distance: 14.00)
#   - Sivala (Distance: 14.00)
#   - Rancer (Distance: 14.00)
#   - Kinakka (Distance: 15.00)
#
# --- Uoyonen (The Forge) (0.7) — Okomon ---
# Score: 1611.00
# Quiet Factor: 221.70
# Avg Nearby HS Quietness (≤ 5 jumps): 238.27
# Nearby HS Systems: 22.00
# Nearby LS Systems in range: 98.00
# Avg LS Distance: 12.44
# LS system distance distribution:
#   - 1 at distance 4
#   - 2 at distance 5
#   - 2 at distance 6
#   - 2 at distance 7
#   - 1 at distance 8
#   - 4 at distance 9
#   - 4 at distance 10
#   - 11 at distance 11
#   - 12 at distance 12
#   - 19 at distance 13
#   - 17 at distance 14
#   - 23 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 8.00)
#   - Uedama (Distance: 11.00)
#   - Tama (Distance: 11.00)
#   - Ahbazon (Distance: 11.00)
#   - Passari (Distance: 12.00)
#   - Kubinen (Distance: 12.00)
#   - Sivala (Distance: 12.00)
#   - Aunenen (Distance: 13.00)
#   - Rancer (Distance: 14.00)
#   - Kinakka (Distance: 15.00)
#
# --- Isenairos (The Citadel) (0.8) — Santenpaa ---
# Score: 1786.00
# Quiet Factor: 186.00
# Avg Nearby HS Quietness (≤ 5 jumps): 235.56
# Nearby HS Systems: 14.00
# Nearby LS Systems in range: 98.00
# Avg LS Distance: 12.55
# LS system distance distribution:
#   - 1 at distance 7
#   - 2 at distance 8
#   - 3 at distance 9
#   - 13 at distance 10
#   - 15 at distance 11
#   - 9 at distance 12
#   - 16 at distance 13
#   - 16 at distance 14
#   - 23 at distance 15
# Avoid-list systems (within radius):
#   - Uedama (Distance: 7.00)
#   - Kubinen (Distance: 8.00)
#   - Jita (Distance: 8.00)
#   - Sivala (Distance: 8.00)
#   - Tama (Distance: 8.00)
#   - Passari (Distance: 10.00)
#   - Ahbazon (Distance: 10.00)
#   - Aunenen (Distance: 11.00)
#   - Kinakka (Distance: 13.00)
#   - Rancer (Distance: 13.00)
#   - Old Man Star (Distance: 14.00)
#
# --- Airmia (The Forge) (0.6) — Okkelen ---
# Score: 1836.00
# Quiet Factor: 284.40
# Avg Nearby HS Quietness (≤ 5 jumps): 383.28
# Nearby HS Systems: 21.00
# Nearby LS Systems in range: 105.00
# Avg LS Distance: 12.27
# LS system distance distribution:
#   - 1 at distance 2
#   - 1 at distance 3
#   - 1 at distance 4
#   - 1 at distance 6
#   - 1 at distance 7
#   - 5 at distance 8
#   - 3 at distance 9
#   - 9 at distance 10
#   - 9 at distance 11
#   - 15 at distance 12
#   - 18 at distance 13
#   - 19 at distance 14
#   - 22 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 7.00)
#   - Tama (Distance: 10.00)
#   - Ahbazon (Distance: 10.00)
#   - Passari (Distance: 11.00)
#   - Aunenen (Distance: 12.00)
#   - Uedama (Distance: 12.00)
#   - Kubinen (Distance: 13.00)
#   - Sivala (Distance: 13.00)
#   - Rancer (Distance: 13.00)
#   - Kinakka (Distance: 14.00)
#
# --- Sakkikainen (The Forge) (0.6) — Okkelen ---
# Score: 1836.00
# Quiet Factor: 351.60
# Avg Nearby HS Quietness (≤ 5 jumps): 383.28
# Nearby HS Systems: 21.00
# Nearby LS Systems in range: 105.00
# Avg LS Distance: 12.27
# LS system distance distribution:
#   - 1 at distance 2
#   - 1 at distance 3
#   - 1 at distance 4
#   - 1 at distance 6
#   - 1 at distance 7
#   - 5 at distance 8
#   - 3 at distance 9
#   - 9 at distance 10
#   - 9 at distance 11
#   - 15 at distance 12
#   - 18 at distance 13
#   - 19 at distance 14
#   - 22 at distance 15
# Avoid-list systems (within radius):
#   - Jita (Distance: 7.00)
#   - Tama (Distance: 10.00)
#   - Ahbazon (Distance: 10.00)
#   - Passari (Distance: 11.00)
#   - Aunenen (Distance: 12.00)
#   - Uedama (Distance: 12.00)
#   - Kubinen (Distance: 13.00)
#   - Sivala (Distance: 13.00)
#   - Rancer (Distance: 13.00)
#   - Kinakka (Distance: 14.00)
